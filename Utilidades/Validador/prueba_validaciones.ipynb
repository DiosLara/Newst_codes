# %%
from Validaciones import Validador
import pandas as pd

# %%
df_prueba = pd.DataFrame({'Razon_social':['Hector limon', 'Alberto Alday Lopez', 'Fernanda Peñuelas Martinez'],
                'RFC':['LIPH980528HDFMRC03','ALBT280518HDFX04','FMAP120698HDFMR000'],
                'Subtotal':[105, 107,106],})
df_prueba

# %%
val = Validador(df_prueba)

# %%
val.panorama_grl()
