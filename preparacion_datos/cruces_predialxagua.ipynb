# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import sys

# %%
ixta_c = gpd.read_file(r"C:\Users\mfpen\Pictures\Ixtapan nueva salida\salidas3\ixtapan_casas_nuevomodeloa22_mod4_5_80.shp")
ixta_c

# %%
ixta_t=gpd.read_file(r"C:\Users\mfpen\Pictures\Ixtapan nueva salida\salidas3\ixtapan_terrenos_nuevomodeloa22_mod4_5_80.shp")
ixta_t

# %%
CURT_I=gpd.read_file(r"D:\Secretaría\CURT\060 Ixtapan de la Sal\predios_060.shp")
CURT_I

# %%
CURT_I['CLAVECATASTRAL']= CURT_I['id_cat']
CURT_I['CLAVE_CATASTRAL']=CURT_I['CLAVECATASTRAL'].str.slice(0,10)
CURT_I

# %%
CURT_I = CURT_I.set_geometry('geometry')

# %%
CURT_I['geometry']=CURT_I.centroid

# %%
#CURT_I['CLAVE_CATASTRAL']=CURT_I['CLAVE_CATASTRAL'].str.slice(0,10)
CURT_I['LATITUD']= CURT_I['geometry'].y
CURT_I['LONGITUD']= CURT_I['geometry'].x
CURT_I

# %%
Predial_Ixta = pd.read_excel(r"D:\Secretaría\cruces_bases\ANEXO 3 PRED DICIEMBRE 2022 - Arturo Baez.xlsx")
Predial_Ixta

# %%
Predial_Ixta['CLAVE_CATASTRAL']=Predial_Ixta.CLAVECATASTRAL.str.slice(0,10)
Predial_Ixta

# %%
CURT_I.columns, Predial_Ixta.columns

# %%
Predial_Ixta.columns[Predial_Ixta.columns.isin(CURT_I.columns)]
falta= Predial_Ixta.columns[~Predial_Ixta.columns.isin(CURT_I.columns)]
falta

# %%
cruce_cat=pd.merge(Predial_Ixta[['CLAVE_CATASTRAL','No. CONSECUTIVO', 'DOMICILIO', 'NOMBRE DEL PROPIETARIO', 'RFC',
       'ESTATUS DE LA CLAVE', 'VALOR CATASTRAL', 'SUPERFICIE DE TERRENO',
       'USO DE ÁREA HOMOGÉNEA', 'PERIODO DE RECAUDACION CORRIENTE REZAGO',
       'PERIODO DE RECAUDACION CORRIENTE', 'EJERCICIO FISCAL']],CURT_I, on="CLAVE_CATASTRAL", how='outer', indicator=True )

# %%
Ixta_curt = cruce_cat

# %%
Ixta_curt

# %%
Ixta_curt = Ixta_curt.drop('_merge', axis=1)

# %%
cruce_cat.to_excel(r"C:\Users\mfpen\OneDrive\Documentos\Secretaría\cruces_predial_agua/cruce_curt_predial_Ixtapan1.xlsx")

# %%
pred_pred=pd.read_excel(r"D:\Secretaría\cruces_bases\Ixtapan de La Sal_PREDIAL.xlsx")
pred_pred

# %%
pred_prop = pd.read_excel(r"D:\Secretaría\cruces_bases\Ixtapan de La Sal_PROPIETARIO.xlsx")
pred_prop

# %%
pred_deu = pd.read_excel(r"D:\Secretaría\cruces_bases\Ixtapan de La Sal_PREDIALADEUDO.xlsx")
pred_deu

# %%
def delete_empty(df):

    for i in df.columns:
        df.loc[(df[i] =="") |(df[i] =="0") | (df[i] ==0) | (df[i].isna()) | (df[i] ==" " ), i]=float('Nan')
    df.dropna(axis=1, how='all', inplace=True)
    
    return df

# %%
delete_empty(pred_prop)

# %%
delete_empty(pred_pred)

# %%
pred_deu_2021 = pred_deu[pred_deu['EJERCICIO'] == 2021]

# %%
pred_deu_2021

# %%
#pred_pred['CLAVE_CATASTRAL']= pred_pred.CLAVECATASTRAL.str.slice(0,10)
#pred_prop['CLAVE_CATASTRAL']= pred_pred.CLAVECATASTRAL.str.slice(0,10)
pred_deu_2021['CLAVE_CATASTRAL']= pred_pred.CLAVECATASTRAL.str.slice(0,10)

# %% [markdown]
# Qué columnas están dentro de mi base x cruzar, que no están dentro de la 1ra base

# %%
pred_pred.columns[pred_pred.columns.isin(pred_prop.columns)]
falta= pred_pred.columns[~pred_pred.columns.isin(pred_prop.columns)]
falta

# %% [markdown]
# Se hace el cruce con las columnas que no están dentro de la 1er base + la llave

# %%
predial_general = pd.merge(pred_pred[['CLAVE_CATASTRAL','CLAVEMANZANA', 'CLAVEZONA', 'DIRECCION', 'VALORTERRENO',
       'VALORTERRENOCOMUN', 'VALORCONSTPROP', 'VALORCONSTCOMUN', 'SUPERFICIE',
       'SUPERFICIETERRCOMUN', 'SUPERFICIECONST', 'SUPERFICIECONSTCOMUN',
       'CLAVEANTERIOR', 'FECHAALTA']],pred_prop, on="CLAVE_CATASTRAL", how="inner")
predial_general

# %%
predial_general

# %%
predial_general.columns[predial_general.columns.isin(pred_deu_2021.columns)]
falta_deu= predial_general.columns[~predial_general.columns.isin(pred_deu_2021.columns)]
falta_deu

# %%
cruce_pred1=pd.merge(predial_general[['CLAVE_CATASTRAL','CLAVEMANZANA', 'CLAVEZONA', 'DIRECCION', 'VALORTERRENO',
       'VALORTERRENOCOMUN', 'VALORCONSTPROP', 'VALORCONSTCOMUN', 'SUPERFICIE',
       'SUPERFICIETERRCOMUN', 'SUPERFICIECONST', 'SUPERFICIECONSTCOMUN',
       'CLAVEANTERIOR', 'FECHAALTA', 'NOMBRE', 'APATERNO', 'AMATERNO', 'RFC',
       'CLAVECP', 'CLAVEMUNICIPIO', 'CLAVEENTIDAD', 'CALLE', 'CLAVESTATUS',
       'CLAVEASENTAMIENTO', 'EMAIL', 'CURP', 'ASENTAMIENTO_NR', 'CLAVECP_NR']],pred_deu_2021, on="CLAVE_CATASTRAL",  how='outer', indicator=True)
#cruce_pred1[cruce_pred1['_merge'] == 'left_only']

# %%
cruce_pred1

# %%
predial_completo = cruce_pred1[cruce_pred1['_merge'] =='both']
predial_sin_adeudos = cruce_pred1[cruce_pred1['_merge'] =='left_only']

# %%
predial_completo

# %%
predial_completo.to_excel(r"D:\Secretaría\cruces_bases\Predial_bases_cruce/predial_completo_ixtapan_1.xlsx")
#predial_sin_adeudos.to_excel(r"D:\Secretaría\cruces_bases\Predial_bases_cruce/predial_no_adeudos_ixtapan_1.xlsx")

# %%
predial_completo=predial_completo.drop(['_merge'], axis=1)

# %%
predial_completo.columns[predial_completo.columns.isin(Ixta_curt.columns)]
falta_pred_completo= predial_completo.columns[~predial_completo.columns.isin(Ixta_curt.columns)]
falta_pred_completo

# %%
cruce_CURT_predial = pd.merge(predial_completo[['CLAVE_CATASTRAL','CLAVEMANZANA', 'CLAVEZONA', 'DIRECCION', 'VALORTERRENO',
       'VALORTERRENOCOMUN', 'VALORCONSTPROP', 'VALORCONSTCOMUN', 'SUPERFICIE',
       'SUPERFICIETERRCOMUN', 'SUPERFICIECONST', 'SUPERFICIECONSTCOMUN',
       'CLAVEANTERIOR', 'FECHAALTA', 'NOMBRE', 'APATERNO', 'AMATERNO',
       'CLAVECP', 'CLAVEMUNICIPIO', 'CLAVEENTIDAD', 'CALLE', 'CLAVESTATUS',
       'CLAVEASENTAMIENTO', 'EMAIL', 'CURP', 'ASENTAMIENTO_NR', 'CLAVECP_NR',
       'EJERCICIO', 'CLAVEPERIODOINI', 'CLAVEPERIODOFIN', 'VALORCATASTRAL',
       'STATUS']], Ixta_curt, on='CLAVE_CATASTRAL', how = 'outer', indicator=True)

# %%
Cruce_CURT_predial = cruce_CURT_predial.rename(columns = {'_merge' : 'cruce_predial_2_CURT'})

# %%
Cruce_CURT_predial[Cruce_CURT_predial.LATITUD.isna()]

# %% [markdown]
# Agregar LAT LON a los registros que no venían en la base de CURT

# %%
Cruce_CURT_predial.loc[Cruce_CURT_predial['LATITUD'].isna(), 'LATITUD'] = 18
Cruce_CURT_predial.loc[Cruce_CURT_predial['LONGITUD'].isna(), 'LONGITUD'] = -99

# %%
#cruce_CURT_predial.to_excel(r"D:\Secretaría\cruces_bases\Predial_bases_cruce/cruce_predial_curt.xlsx")
cruce_CURT_predial.to_csv(r"D:\Secretaría\cruces_bases\Predial_bases_cruce/cruce_predial_curt.csv",encoding='utf-8-sig',index=False)

# %%
from shapely.geometry import Point

# %%
geometry = [Point(xy) for xy in zip(Cruce_CURT_predial.LONGITUD,Cruce_CURT_predial.LATITUD)]
gdf = gpd.GeoDataFrame(Cruce_CURT_predial, geometry=geometry)
gdf

# %%
gdf.to_file(r"D:\Secretaría\cruces_bases\Predial_bases_cruce\cruce_predial_curt.shp", )

# %%
cruce_CURT_predial = pd.read_excel(r"D:\Secretaría\cruces_bases\Predial_bases_cruce\cruce_predial_curt.xlsx")

# %%
cruce_CURT_predial['ESTIMADO'] = cruce_CURT_predial['CURT'].count()

# %%
tem_igecem.merge(BPCE.groupby('CVEGEO').count().reset_index()[['ESTIMADO', 'CURT', 'CVEGEO']],on='CVEGEO')

# %%
cruce_CURT_predial.groupby([''])

# %%
import sys
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
import concurrent.futures
sys.path.append(r'C:\Users\dlara\Proyectos_git\geoloc2\puntos_sobre_poligono')
from simulacion_interpolacion import *

# %%
import tqdm as tqdm
funcion= task_chunks

# %%
# test_igecem = prep.data_prep_catastro(path_base, path_shp)
from tqdm import tqdm
import os
test_igecem= pd.read_csv(r'C:\Users\dlara\Downloads\test_igecem_ch.csv', encoding='utf-8-sig')
test_igecem_chunks =  np.array_split(test_igecem, os.cpu_count()-1) ##Aqui se especifica si se requiere un loc y los chunks

df_concat = pd.DataFrame()

with concurrent.futures.ThreadPoolExecutor() as executor:
    for df_chunk in tqdm(zip(executor.map(funcion, test_igecem_chunks)),total = len(test_igecem_chunks)):
        df_concat = pd.concat([df_chunk[0],df_concat], axis=0)
# Out:
#   0%|          | 0/334 [00:00<?, ?it/s]
# 600113801000000
# 600119811000000
#   0%|          | 1/334 [00:00<01:20,  4.13it/s]
# 600113827000000
# 600113825000000
# 600113824000000
# 600119707000000
#   0%|          | 0/334 [00:00<?, ?it/s]
# 600101032000000
# 600101050000000
#   0%|          | 0/334 [00:00<?, ?it/s]
# 600101128000000
# 600113504000000
# 600107306000000
# 600127751000000
# 600127742000000
#   0%|          | 0/333 [00:00<?, ?it/s]
# 600127750000000
# 600116218000000
# 600116217000000
# 600116244000000
# 600119002000000
#   0%|          | 0/334 [00:00<?, ?it/s]
# 600119415000000
#   1%|          | 4/334 [00:01<00:27, 12.11it/s]
# 600105621000000
# 600105687000000
# 600105675000000
# 600113809000000
# 600113810000000
# 600119715000000
#   0%|          | 0/333 [00:00<?, ?it/s]
# 600800832000000
#   1%|          | 3/334 [00:00<00:18, 18.35it/s]
# 600801150000000
# 600802721000000
# 600101934000000
#   0%|          | 0/333 [00:00<?, ?it/s]
# 600100851000000
# 600404806000000
#   1%|          | 2/334 [00:00<00:18, 17.79it/s]
# 600404816000000
# 600108402000000
# 600108401000000
# 600120139000000
#   1%|          | 3/333 [00:00<00:21, 15.13it/s]
# 600127743000000
# 600127741000000
# 600116245000000
# 600116248000000
# 600119506000000
# 600118516000000
#   2%|▏         | 6/334 [00:02<01:17,  4.25it/s]
# 600105659000000
# 600105629000000
# 600108606000000
# 600105658000000
# 600113811000000
#   1%|          | 3/334 [00:02<02:39,  2.07it/s]
# 600130432000000
# 600116015000000
# 600116006000000
# 600101658000000
# 600903307000000
# 600115043000000
# 600605901000000
# 600123791000000
# 600103519000000
#   1%|          | 4/334 [00:02<01:46,  3.10it/s]
# 600103525000000
# 600113510000000
# 600404229000000
# 600801454000000
# 600127725000000
# 600116247000000
# 600127755000000
#   0%|          | 0/15 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 7/334 [00:03<02:14,  2.42it/s]
# 600109204000000
# 600109205000000
# 600119507000000
# 600109919000000
# 600102331000000
# 600113812000000
#   1%|          | 4/334 [00:03<03:48,  1.45it/s]
# 600102315000000
# 600110410000000
# 600116307000000
# 600116246000000
# 600605733000000
# 600133238000000
#   1%|          | 4/333 [00:02<01:51,  2.96it/s]
# 600913503000000
# 600103524000000
# 600103522000000
# 600113509000000
# 600403630000000
#   2%|▏         | 6/333 [00:02<02:30,  2.17it/s]
# 600902294000000
# 600713808000000
# 600127724000000
# 600109208000000
# 600109212000000
#   2%|▏         | 8/334 [00:03<03:05,  1.76it/s]
# 600133233000000
# 600109924000000
# 600113817000000
# 600102228000000
# 600110409000000
# 600116240000000
#   2%|▏         | 6/333 [00:02<02:32,  2.14it/s]
# 600132601000000
# 600119907000000
# 600505142000000
# 600110508000000
# 600113528000000
#   1%|          | 4/333 [00:01<01:39,  3.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 6/333 [00:03<03:30,  1.56it/s]
# 600901940000000
# 600116333000000
# 600127752000000
# 600109225000000
#   3%|▎         | 9/334 [00:04<03:24,  1.59it/s]
# 600119927000000
# 600109925000000
# 600113821000000
# 600102207000000
# 600133236000000
# 600116239000000
# 600904021000000
# 600119917000000
# 600401530000000
#   2%|▏         | 5/333 [00:02<02:21,  2.32it/s]
# 600110509000000
# 600113529000000
# 600605007000000
# 600116332000000
# 600127753000000
# 600109226000000
#   3%|▎         | 10/334 [00:05<03:29,  1.54it/s]
# 600119921000000
# 600109921000000
# 600113818000000
# 600105678000000
#   2%|▏         | 7/334 [00:05<04:14,  1.28it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 7/333 [00:04<03:22,  1.61it/s]
# 600133237000000
# 600116243000000
# 600901914000000
# 600119919000000
# 600605169000000
# 600103537000000
# 600107326000000
# 600605078000000
# 600116330000000
#   3%|▎         | 11/333 [00:05<02:59,  1.79it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 11/334 [00:06<03:34,  1.51it/s]
#
#
#
#
#
#   3%|▎         | 11/334 [00:05<02:57,  1.82it/s]
# 600120402000000
# 600109114000000
# 600119918000000
# 600109901000000
# 600113819000000
#   3%|▎         | 10/334 [00:05<03:39,  1.48it/s]
# 600102346000000
# 600123011000000
# 600116242000000
# 600200501000000
#   3%|▎         | 10/333 [00:05<03:33,  1.52it/s]
# 600119920000000
# 600502632000000
# 600110510000000
# 600107303000000
# 600601508000000
#   4%|▎         | 12/334 [00:06<03:39,  1.46it/s]
# 600116331000000
# 600120414000000
# 600109115000000
# 600119916000000
# 600109914000000
# 600113314000000
# 600105677000000
# 600123010000000
# 600116241000000
# 600600108000000
#   3%|▎         | 11/334 [00:06<03:45,  1.43it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 11/333 [00:06<03:38,  1.47it/s]
# 600119922000000
# 600901436000000
# 600103521000000
# 600107302000000
# 600601618000000
#   4%|▍         | 13/334 [00:07<03:42,  1.44it/s]
# 600116329000000
# 600127766000000
# 600110747000000
# 600119908000000
# 600108602000000
# 600113311000000
#   4%|▍         | 13/334 [00:06<03:22,  1.59it/s]
# 600102380000000
# 600121411000000
# 600117744000000
# 600600115000000
# 600119923000000
#   4%|▍         | 14/333 [00:07<03:27,  1.54it/s]
# 600901437000000
# 600103511000000
# 600107301000000
# 600601606000000
# 600116304000000
#   4%|▍         | 14/334 [00:08<03:40,  1.45it/s]
#
#
#
#
#
#   4%|▍         | 14/334 [00:07<03:25,  1.56it/s]
# 600120413000000
# 600110710000000
# 600119906000000
# 600108601000000
# 600113310000000
# 600102313000000
# 600121402000000
# 600117750000000
# 600600109000000
# 600119924000000
#   3%|▎         | 11/333 [00:07<03:39,  1.46it/s]
# 600112204000000
# 600103510000000
# 600104409000000
# 600601654000000
# 600116305000000
#   4%|▍         | 15/334 [00:08<03:42,  1.43it/s]
# 600120729000000
# 600108808000000
# 600119905000000
# 600109912000000
# 600113309000000
#   4%|▍         | 15/334 [00:08<03:31,  1.51it/s]
# 600102366000000
# 600121301000000
# 600117745000000
# 600600111000000
# 600119925000000
# 600105912000000
# 600103535000000
# 600104448000000
# 600601614000000
#   4%|▍         | 14/333 [00:08<03:41,  1.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▍         | 16/334 [00:09<03:43,  1.42it/s]
# 600116306000000
# 600120723000000
# 600108809000000
# 600119904000000
# 600109909000000
# 600113807000000
# 600102312000000
# 600119716000000
# 600117749000000
#   4%|▍         | 14/333 [00:08<03:40,  1.44it/s]
# 600600116000000
# 600119926000000
# 600105911000000
# 600103550000000
#   4%|▍         | 14/334 [00:09<03:45,  1.42it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▎         | 12/333 [00:07<03:38,  1.47it/s]
# 600107973000000
# 600601648000000
# 600116303000000
# 600120618000000
#   5%|▌         | 17/334 [00:10<03:43,  1.42it/s]
# 600108810000000
# 600119903000000
# 600109906000000
# 600104614000000
#   5%|▌         | 17/334 [00:09<03:38,  1.45it/s]
# 600102371000000
# 600119714000000
# 600117748000000
#   5%|▍         | 15/333 [00:09<03:46,  1.40it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 15/334 [00:10<03:52,  1.37it/s]
# 600600103000000
# 600133232000000
# 600105910000000
# 600103548000000
# 600104829000000
# 600601610000000
# 600116302000000
# 600120619000000
# 600601210000000
#   5%|▍         | 15/333 [00:10<03:54,  1.36it/s]
#
#
#
#
#
#
#
#
#   5%|▌         | 18/334 [00:11<03:54,  1.35it/s]
# 600119901000000
# 600109904000000
# 600104613000000
# 600102349000000
# 600119701000000
# 600117706000000
# 600600104000000
# 600123141000000
# 600105909000000
#   4%|▍         | 14/333 [00:09<04:05,  1.30it/s]
# 600103515000000
# 600122861000000
# 600601601000000
# 600116346000000
#   6%|▌         | 19/333 [00:11<04:04,  1.29it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 19/334 [00:12<04:07,  1.27it/s]
#
#
#
#
#
#   6%|▌         | 19/334 [00:11<04:05,  1.28it/s]
# 600120611000000
# 600601221000000
# 600119603000000
# 600109920000000
# 600110925000000
# 600102333000000
# 600119710000000
# 600139757000000
# 600600114000000
# 600120416000000
#   5%|▍         | 16/333 [00:10<04:09,  1.27it/s]
# 600105908000000
# 600103513000000
# 600122875000000
# 600601630000000
# 600116308000000
#   6%|▌         | 20/333 [00:12<04:04,  1.28it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 20/334 [00:12<04:04,  1.29it/s]
# 600120613000000
# 600601213000000
# 600119602000000
# 600109923000000
# 600113822000000
#   6%|▌         | 20/334 [00:11<03:59,  1.31it/s]
# 600102306000000
# 600119717000000
# 600139780000000
# 600121106000000
#   6%|▌         | 19/334 [00:12<04:02,  1.30it/s]
# 600121210000000
# 600601824000000
# 600103512000000
# 600122865000000
#   5%|▍         | 16/333 [00:10<03:58,  1.33it/s]
# 600601615000000
# 600116309000000
# 600120609000000
# 600601111000000
#   5%|▌         | 18/333 [00:12<04:00,  1.31it/s]
#
#
#
#
#
#
#
#
#   6%|▋         | 21/334 [00:13<03:54,  1.33it/s]
# 600119601000000
# 600109922000000
# 600113828000000
# 600102307000000
# 600119702000000
#   5%|▌         | 17/333 [00:11<03:54,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 19/334 [00:13<03:54,  1.34it/s]
# 600139783000000
# 600121107000000
# 600121205000000
# 600406060000000
# 600103527000000
# 600104864000000
# 600601644000000
# 600116310000000
# 600120608000000
# 600601117000000
#   7%|▋         | 22/334 [00:14<03:57,  1.32it/s]
# 600119604000000
# 600108610000000
# 600110805000000
# 600102227000000
# 600119709000000
#   5%|▌         | 18/333 [00:12<03:58,  1.32it/s]
# 600301881000000
# 600904023000000
# 600121211000000
# 600502711000000
# 600114113000000
#   6%|▌         | 20/334 [00:14<03:56,  1.33it/s]
# 600104855000000
# 600601645000000
# 600116221000000
# 600120614000000
#   5%|▌         | 18/333 [00:11<03:55,  1.34it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 23/334 [00:15<03:57,  1.31it/s]
# 600601623000000
# 600119501000000
# 600108611000000
# 600113301000000
# 600102204000000
# 600119713000000
#   6%|▌         | 19/333 [00:12<03:52,  1.35it/s]
# 600804615000000
# 600201036000000
# 600121204000000
# 600502707000000
# 600114112000000
# 600104857000000
# 600601616000000
# 600120607000000
#   7%|▋         | 22/333 [00:14<03:55,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 24/334 [00:15<03:47,  1.36it/s]
# 600116251000000
# 600601643000000
# 600119509000000
# 600108609000000
# 600113419000000
# 600102214000000
# 600119703000000
# 600505122000000
# 600403161000000
# 600121202000000
#   6%|▋         | 21/333 [00:14<03:48,  1.36it/s]
# 600905805000000
# 600113906000000
# 600104549000000
# 600600435000000
# 600120622000000
# 600116334000000
#   6%|▌         | 20/333 [00:13<03:51,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 25/334 [00:16<03:50,  1.34it/s]
# 600601641000000
# 600119512000000
# 600108612000000
# 600113411000000
# 600102221000000
#   7%|▋         | 22/334 [00:16<03:50,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 23/334 [00:16<03:46,  1.38it/s]
# 600119712000000
# 600602913000000
# 600132347000000
# 600121201000000
# 600903905000000
# 600113901000000
# 600104551000000
# 600600451000000
# 600120615000000
# 600116237000000
# 600601609000000
# 600119502000000
#   8%|▊         | 26/334 [00:17<03:35,  1.43it/s]
# 600108604000000
# 600113421000000
# 600102219000000
# 600119708000000
# 600603308000000
# 600119850000000
#   7%|▋         | 25/334 [00:16<03:33,  1.45it/s]
# 600117567000000
# 600905840000000
# 600110506000000
# 600104554000000
# 600117503000000
# 600120605000000
#   8%|▊         | 25/333 [00:16<03:33,  1.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 27/334 [00:17<03:29,  1.46it/s]
# 600116206000000
# 600601620000000
# 600119511000000
# 600109501000000
# 600113403000000
#   8%|▊         | 27/334 [00:16<03:29,  1.46it/s]
# 600102218000000
# 600119704000000
# 600505125000000
# 600801602000000
# 600118412000000
#   7%|▋         | 24/333 [00:16<03:28,  1.48it/s]
# 600122342000000
# 600110515000000
# 600104555000000
# 600131625000000
# 600120606000000
#   8%|▊         | 26/333 [00:17<03:24,  1.50it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 28/334 [00:18<03:22,  1.51it/s]
# 600116205000000
# 600601637000000
# 600119510000000
# 600108305000000
# 600113404000000
# 600102216000000
#   7%|▋         | 25/334 [00:18<03:23,  1.52it/s]
# 600139788000000
# 600903823000000
# 600502953000000
# 600115045000000
# 600606003000000
# 600110514000000
#   8%|▊         | 26/334 [00:18<03:23,  1.51it/s]
# 600104865000000
# 600131623000000
# 600120616000000
# 600116204000000
# 600601636000000
#   8%|▊         | 26/333 [00:18<03:23,  1.51it/s]
#
#
#
#
#
#
#
#
#   9%|▊         | 29/334 [00:18<03:24,  1.49it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 25/333 [00:16<03:22,  1.52it/s]
# 600119513000000
# 600108525000000
# 600113406000000
# 600102206000000
# 600139790000000
# 600200825000000
# 600300339000000
# 600115044000000
# 600606002000000
# 600110501000000
# 600122846000000
#   8%|▊         | 25/333 [00:16<03:20,  1.54it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 30/334 [00:19<03:20,  1.52it/s]
# 600131604000000
# 600120604000000
# 600116249000000
# 600601635000000
# 600119514000000
# 600108605000000
# 600113405000000
# 600102205000000
# 600139791000000
# 600301859000000
# 600300315000000
# 600119902000000
# 600303037000000
# 600110502000000
# 600104850000000
# 600131641000000
# 600120601000000
#   9%|▊         | 29/333 [00:19<03:18,  1.53it/s]
# 600116207000000
# 600601628000000
# 600119003000000
# 600109907000000
#   9%|▉         | 31/334 [00:20<03:18,  1.53it/s]
# 600102202000000
# 600113416000000
# 600139720000000
# 600105905000000
# 600300314000000
# 600119412000000
#   8%|▊         | 28/333 [00:19<03:17,  1.55it/s]
# 600610002000000
# 600110512000000
# 600104852000000
# 600131605000000
# 600120621000000
#   9%|▉         | 30/333 [00:19<03:12,  1.57it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 32/334 [00:20<03:14,  1.56it/s]
# 600116202000000
# 600601617000000
# 600119004000000
# 600101420000000
# 600102212000000
# 600113415000000
# 600139729000000
# 600105906000000
# 600300310000000
#   9%|▉         | 31/334 [00:20<03:12,  1.57it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 33/333 [00:20<03:11,  1.57it/s]
# 600100107000000
# 600300912000000
# 600110503000000
# 600104802000000
# 600131640000000
# 600120603000000
# 600116201000000
# 600601651000000
# 600120219000000
# 600109913000000
#  10%|▉         | 33/334 [00:21<03:14,  1.55it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 32/334 [00:21<03:16,  1.54it/s]
# 600102203000000
# 600113412000000
# 600139730000000
# 600112283000000
# 600304219000000
# 600131628000000
# 600401405000000
# 600110513000000
# 600104849000000
#   9%|▊         | 29/333 [00:19<03:17,  1.54it/s]
# 600131622000000
# 600120617000000
# 600116210000000
# 600110116000000
# 600119015000000
# 600101413000000
#  10%|█         | 34/334 [00:22<03:16,  1.53it/s]
# 600170178000000
# 600113315000000
# 600139728000000
# 600139782000000
# 600303863000000
# 600100515000000
#   9%|▉         | 31/333 [00:20<03:18,  1.52it/s]
# 600401529000000
# 600110511000000
# 600104813000000
# 600131606000000
# 600120409000000
#  10%|▉         | 33/333 [00:21<03:16,  1.53it/s]
# 600116227000000
# 600107818000000
# 600118823000000
# 600101427000000
#  10%|█         | 35/334 [00:22<03:14,  1.54it/s]
# 600170162000000
# 600113826000000
# 600139727000000
# 600602406000000
# 600302062000000
# 600104520000000
#  10%|▉         | 32/333 [00:21<03:13,  1.56it/s]
# 600401528000000
# 600103444000000
# 600104827000000
# 600131620000000
# 600120408000000
# 600116228000000
#   9%|▉         | 31/333 [00:20<03:13,  1.56it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 36/334 [00:23<03:12,  1.55it/s]
# 600110007000000
# 600118801000000
# 600101403000000
# 600102166000000
# 600113306000000
#  10%|▉         | 32/333 [00:21<03:12,  1.57it/s]
# 600602408000000
# 600139725000000
# 600602405000000
# 600104873000000
# 600406165000000
#  10%|▉         | 32/333 [00:21<03:13,  1.56it/s]
# 600103201000000
# 600104816000000
# 600131607000000
# 600120411000000
# 600116229000000
#  10%|▉         | 32/333 [00:21<03:11,  1.57it/s]
# Canceled future for execute_request message before replies were done

# %%
PATH_BASE = r'C:\Users\dlara\Downloads\crucexcurt_Ixtapan.xlsx'
PATH_SHP  = r"C:\Users\dlara\Downloads\curt_ixtapan_completa\curt_ixtapan_completa.shp"

df_final_catastro = post_points_catastro(PATH_BASE, PATH_SHP, task_chunks)

# print(df_final_catastro)    

df_final_catastro.to_csv(r'C:\Users\dlara/Ixtapan_puntos.csv', encoding='utf-8-sig')
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\dlara\anaconda3\lib\xml\etree\ElementTree.py:1720 in feed
#     self.parser.Parse(data, False)
#
# ExpatError: mismatched tag: line 2, column 43924
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3460 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[6], line 4
#     df_final_catastro = post_points_catastro(PATH_BASE, PATH_SHP, task_chunks)
#
#   File ~\Proyectos_git\geoloc2\puntos_sobre_poligono\simulacion_interpolacion.py:432 in post_points_catastro
#     test_igecem = prep.data_prep_catastro(path_base, path_shp)
#
#   File ~\Proyectos_git\geoloc2\preparacion_datos\src\preparacion_inter_puntos.py:192 in data_prep_catastro
#     BPCE = pd.read_excel(path_base)
#
#   File c:\Users\dlara\anaconda3\lib\site-packages\pandas\util\_decorators.py:211 in wrapper
#     return func(*args, **kwargs)
#
#   File c:\Users\dlara\anaconda3\lib\site-packages\pandas\util\_decorators.py:331 in wrapper
#     return func(*args, **kwargs)
#
#   File c:\Users\dlara\anaconda3\lib\site-packages\pandas\io\excel\_base.py:482 in read_excel
#     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#
#   File c:\Users\dlara\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1695 in __init__
#     self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
#   File c:\Users\dlara\anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:557 in __init__
#     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
#   File c:\Users\dlara\anaconda3\lib\site-packages\pandas\io\excel\_base.py:545 in __init__
#     self.book = self.load_workbook(self.handles.handle)
#
#   File c:\Users\dlara\anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:568 in load_workbook
#     return load_workbook(
#
#   File c:\Users\dlara\anaconda3\lib\site-packages\openpyxl\reader\excel.py:317 in load_workbook
#     reader.read()
#
#   File c:\Users\dlara\anaconda3\lib\site-packages\openpyxl\reader\excel.py:277 in read
#     self.read_strings()
#
#   File c:\Users\dlara\anaconda3\lib\site-packages\openpyxl\reader\excel.py:144 in read_strings
#     self.shared_strings = read_string_table(src)
#
#   File c:\Users\dlara\anaconda3\lib\site-packages\openpyxl\reader\strings.py:15 in read_string_table
#     for _, node in iterparse(xml_source):
#
#   File c:\Users\dlara\anaconda3\lib\xml\etree\ElementTree.py:1254 in iterator
#     yield from pullparser.read_events()
#
#   File c:\Users\dlara\anaconda3\lib\xml\etree\ElementTree.py:1329 in read_events
#     raise event
#
#   File c:\Users\dlara\anaconda3\lib\xml\etree\ElementTree.py:1301 in feed
#     self._parser.feed(data)
#
#   File c:\Users\dlara\anaconda3\lib\xml\etree\ElementTree.py:1722 in feed
#     self._raiseerror(v)
#
#   File c:\Users\dlara\anaconda3\lib\xml\etree\ElementTree.py:1629 in _raiseerror
#     raise err
#
#   File <string>
# ParseError: mismatched tag: line 2, column 43924
