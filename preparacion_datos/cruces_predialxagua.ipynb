# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import sys

# %%
ixta_c = gpd.read_file(r"C:\Users\mfpen\Pictures\Ixtapan nueva salida\salidas3\ixtapan_casas_nuevomodeloa22_mod4_5_80.shp")
ixta_c

# %%
ixta_t=gpd.read_file(r"C:\Users\mfpen\Pictures\Ixtapan nueva salida\salidas3\ixtapan_terrenos_nuevomodeloa22_mod4_5_80.shp")
ixta_t

# %%
CURT_I=gpd.read_file(r"D:\Secretaría\CURT\060 Ixtapan de la Sal\predios_060.shp")
CURT_I

# %%
CURT_I['CLAVECATASTRAL']= CURT_I['id_cat']
CURT_I['CLAVE_CATASTRAL']=CURT_I['CLAVECATASTRAL'].str.slice(0,10)
CURT_I

# %%
CURT_I = CURT_I.set_geometry('geometry')

# %%
CURT_I['geometry']=CURT_I.centroid

# %%
#CURT_I['CLAVE_CATASTRAL']=CURT_I['CLAVE_CATASTRAL'].str.slice(0,10)
CURT_I['LATITUD']= CURT_I['geometry'].y
CURT_I['LONGITUD']= CURT_I['geometry'].x
CURT_I

# %%
Predial_Ixta = pd.read_excel(r"D:\Secretaría\cruces_bases\ANEXO 3 PRED DICIEMBRE 2022 - Arturo Baez.xlsx")
Predial_Ixta

# %%
Predial_Ixta['CLAVE_CATASTRAL']=Predial_Ixta.CLAVECATASTRAL.str.slice(0,10)
Predial_Ixta

# %%
CURT_I.columns, Predial_Ixta.columns

# %%
Predial_Ixta.columns[Predial_Ixta.columns.isin(CURT_I.columns)]
falta= Predial_Ixta.columns[~Predial_Ixta.columns.isin(CURT_I.columns)]
falta

# %%
cruce_cat=pd.merge(Predial_Ixta[['CLAVE_CATASTRAL','No. CONSECUTIVO', 'DOMICILIO', 'NOMBRE DEL PROPIETARIO', 'RFC',
       'ESTATUS DE LA CLAVE', 'VALOR CATASTRAL', 'SUPERFICIE DE TERRENO',
       'USO DE ÁREA HOMOGÉNEA', 'PERIODO DE RECAUDACION CORRIENTE REZAGO',
       'PERIODO DE RECAUDACION CORRIENTE', 'EJERCICIO FISCAL']],CURT_I, on="CLAVE_CATASTRAL", how='outer', indicator=True )

# %%
Ixta_curt = cruce_cat

# %%
Ixta_curt

# %%
Ixta_curt = Ixta_curt.drop('_merge', axis=1)

# %%
cruce_cat.to_excel(r"C:\Users\mfpen\OneDrive\Documentos\Secretaría\cruces_predial_agua/cruce_curt_predial_Ixtapan1.xlsx")

# %%
pred_pred=pd.read_excel(r"D:\Secretaría\cruces_bases\Ixtapan de La Sal_PREDIAL.xlsx")
pred_pred

# %%
pred_prop = pd.read_excel(r"D:\Secretaría\cruces_bases\Ixtapan de La Sal_PROPIETARIO.xlsx")
pred_prop

# %%
pred_deu = pd.read_excel(r"D:\Secretaría\cruces_bases\Ixtapan de La Sal_PREDIALADEUDO.xlsx")
pred_deu

# %%
def delete_empty(df):

    for i in df.columns:
        df.loc[(df[i] =="") |(df[i] =="0") | (df[i] ==0) | (df[i].isna()) | (df[i] ==" " ), i]=float('Nan')
    df.dropna(axis=1, how='all', inplace=True)
    
    return df

# %%
delete_empty(pred_prop)

# %%
delete_empty(pred_pred)

# %%
pred_deu_2021 = pred_deu[pred_deu['EJERCICIO'] == 2021]

# %%
pred_deu_2021

# %%
#pred_pred['CLAVE_CATASTRAL']= pred_pred.CLAVECATASTRAL.str.slice(0,10)
#pred_prop['CLAVE_CATASTRAL']= pred_pred.CLAVECATASTRAL.str.slice(0,10)
pred_deu_2021['CLAVE_CATASTRAL']= pred_pred.CLAVECATASTRAL.str.slice(0,10)

# %% [markdown]
# Qué columnas están dentro de mi base x cruzar, que no están dentro de la 1ra base

# %%
pred_pred.columns[pred_pred.columns.isin(pred_prop.columns)]
falta= pred_pred.columns[~pred_pred.columns.isin(pred_prop.columns)]
falta

# %% [markdown]
# Se hace el cruce con las columnas que no están dentro de la 1er base + la llave

# %%
predial_general = pd.merge(pred_pred[['CLAVE_CATASTRAL','CLAVEMANZANA', 'CLAVEZONA', 'DIRECCION', 'VALORTERRENO',
       'VALORTERRENOCOMUN', 'VALORCONSTPROP', 'VALORCONSTCOMUN', 'SUPERFICIE',
       'SUPERFICIETERRCOMUN', 'SUPERFICIECONST', 'SUPERFICIECONSTCOMUN',
       'CLAVEANTERIOR', 'FECHAALTA']],pred_prop, on="CLAVE_CATASTRAL", how="inner")
predial_general

# %%
predial_general

# %%
predial_general.columns[predial_general.columns.isin(pred_deu_2021.columns)]
falta_deu= predial_general.columns[~predial_general.columns.isin(pred_deu_2021.columns)]
falta_deu

# %%
cruce_pred1=pd.merge(predial_general[['CLAVE_CATASTRAL','CLAVEMANZANA', 'CLAVEZONA', 'DIRECCION', 'VALORTERRENO',
       'VALORTERRENOCOMUN', 'VALORCONSTPROP', 'VALORCONSTCOMUN', 'SUPERFICIE',
       'SUPERFICIETERRCOMUN', 'SUPERFICIECONST', 'SUPERFICIECONSTCOMUN',
       'CLAVEANTERIOR', 'FECHAALTA', 'NOMBRE', 'APATERNO', 'AMATERNO', 'RFC',
       'CLAVECP', 'CLAVEMUNICIPIO', 'CLAVEENTIDAD', 'CALLE', 'CLAVESTATUS',
       'CLAVEASENTAMIENTO', 'EMAIL', 'CURP', 'ASENTAMIENTO_NR', 'CLAVECP_NR']],pred_deu_2021, on="CLAVE_CATASTRAL",  how='outer', indicator=True)
#cruce_pred1[cruce_pred1['_merge'] == 'left_only']

# %%
cruce_pred1

# %%
predial_completo = cruce_pred1[cruce_pred1['_merge'] =='both']
predial_sin_adeudos = cruce_pred1[cruce_pred1['_merge'] =='left_only']

# %%
predial_completo

# %%
predial_completo.to_excel(r"D:\Secretaría\cruces_bases\Predial_bases_cruce/predial_completo_ixtapan_1.xlsx")
#predial_sin_adeudos.to_excel(r"D:\Secretaría\cruces_bases\Predial_bases_cruce/predial_no_adeudos_ixtapan_1.xlsx")

# %%
predial_completo=predial_completo.drop(['_merge'], axis=1)

# %%
predial_completo.columns[predial_completo.columns.isin(Ixta_curt.columns)]
falta_pred_completo= predial_completo.columns[~predial_completo.columns.isin(Ixta_curt.columns)]
falta_pred_completo

# %%
cruce_CURT_predial = pd.merge(predial_completo[['CLAVE_CATASTRAL','CLAVEMANZANA', 'CLAVEZONA', 'DIRECCION', 'VALORTERRENO',
       'VALORTERRENOCOMUN', 'VALORCONSTPROP', 'VALORCONSTCOMUN', 'SUPERFICIE',
       'SUPERFICIETERRCOMUN', 'SUPERFICIECONST', 'SUPERFICIECONSTCOMUN',
       'CLAVEANTERIOR', 'FECHAALTA', 'NOMBRE', 'APATERNO', 'AMATERNO',
       'CLAVECP', 'CLAVEMUNICIPIO', 'CLAVEENTIDAD', 'CALLE', 'CLAVESTATUS',
       'CLAVEASENTAMIENTO', 'EMAIL', 'CURP', 'ASENTAMIENTO_NR', 'CLAVECP_NR',
       'EJERCICIO', 'CLAVEPERIODOINI', 'CLAVEPERIODOFIN', 'VALORCATASTRAL',
       'STATUS']], Ixta_curt, on='CLAVE_CATASTRAL', how = 'outer', indicator=True)

# %%
Cruce_CURT_predial = cruce_CURT_predial.rename(columns = {'_merge' : 'cruce_predial_2_CURT'})

# %%
Cruce_CURT_predial[Cruce_CURT_predial.LATITUD.isna()]

# %% [markdown]
# Agregar LAT LON a los registros que no venían en la base de CURT

# %%
Cruce_CURT_predial.loc[Cruce_CURT_predial['LATITUD'].isna(), 'LATITUD'] = 18
Cruce_CURT_predial.loc[Cruce_CURT_predial['LONGITUD'].isna(), 'LONGITUD'] = -99

# %%
#cruce_CURT_predial.to_excel(r"D:\Secretaría\cruces_bases\Predial_bases_cruce/cruce_predial_curt.xlsx")
cruce_CURT_predial.to_csv(r"D:\Secretaría\cruces_bases\Predial_bases_cruce/cruce_predial_curt.csv",encoding='utf-8-sig',index=False)

# %%
from shapely.geometry import Point

# %%
geometry = [Point(xy) for xy in zip(Cruce_CURT_predial.LONGITUD,Cruce_CURT_predial.LATITUD)]
gdf = gpd.GeoDataFrame(Cruce_CURT_predial, geometry=geometry)
gdf

# %%
gdf.to_file(r"D:\Secretaría\cruces_bases\Predial_bases_cruce\cruce_predial_curt.shp", )

# %%
cruce_CURT_predial = pd.read_excel(r"D:\Secretaría\cruces_bases\Predial_bases_cruce\cruce_predial_curt.xlsx")

# %%
cruce_CURT_predial['ESTIMADO'] = cruce_CURT_predial['CURT'].count()

# %%
tem_igecem.merge(BPCE.groupby('CVEGEO').count().reset_index()[['ESTIMADO', 'CURT', 'CVEGEO']],on='CVEGEO')

# %%
cruce_CURT_predial.groupby([''])

# %%
import sys
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
import concurrent.futures
sys.path.append(r'C:\Users\dlara\Proyectos_git\geoloc2\puntos_sobre_poligono')
from simulacion_interpolacion import task_chunks
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\dlara\Proyectos_git\geoloc2\preparacion_datos\cruces_predialxagua.ipynb Cell 54 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/dlara/Proyectos_git/geoloc2/preparacion_datos/cruces_predialxagua.ipynb#Y104sZmlsZQ%3D%3D?line=0'>1</a> import concurrent.futures
#       <a href='vscode-notebook-cell:/c%3A/Users/dlara/Proyectos_git/geoloc2/preparacion_datos/cruces_predialxagua.ipynb#Y104sZmlsZQ%3D%3D?line=1'>2</a> sys.path.append(r'C:\Users\dlara\Proyectos_git\geoloc2\puntos_sobre_poligono')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dlara/Proyectos_git/geoloc2/preparacion_datos/cruces_predialxagua.ipynb#Y104sZmlsZQ%3D%3D?line=2'>3</a> from simulacion_interpolacion import task_chunks
#
# File ~\Proyectos_git\geoloc2\puntos_sobre_poligono\simulacion_interpolacion.py:13, in <module>
#      11 import sys
#      12 sys.path.append(r'C:\Users\dlara\Proyectos_git\geoloc2\preparacion_datos\src')
# ---> 13 from preparacion_inter_puntos import prep
#      14 '''Interpolación de puntos'''
#      15 def _to_2d(x, y, z):
#
# File ~\Proyectos_git\geoloc2\preparacion_datos\src\preparacion_inter_puntos.py:10, in <module>
#       8 #from OracleIntfis.db_connection import OracleDB
#       9 import os
# ---> 10 from scipy.spatial import cKDTree
#      11 from shapely.geometry import Point
#      12 from dataprep.clean import clean_lat_long
#
# ModuleNotFoundError: No module named 'scipy'

# %%
import tqdm as tqdm
funcion= task_chunks

# %%
test_igecem
# Out:
#       Unnamed: 0  cve_ent  cve_mun  cve_loc           id_cat proceso  \
# 0           6722       15       60        0  600113801000000       G
# 1           6721       15       60        0  600113827000000       G
# 2           6720       15       60        0  600113825000000       G
# 3           6719       15       60        0  600113824000000       G
# 4           6718       15       60        0  600113809000000       G
# ...          ...      ...      ...      ...              ...     ...
# 4995        2515       15       60        0  600139941000000       G
# 4996        2514       15       60        0  600139946000000       G
# 4997        2513       15       60        0  600139947000000       G
# 4998        2512       15       60        0  600139955000000       G
# 4999        7201       15       60        0  600120005000000       G
#
#                        curt  notas   CLAVECATASTRAL  CLAVE_CATA    LATITUD  \
# 0     185102565509940306338    NaN  600113801000000   600113801  18.850713
# 1     185102461609940313777    NaN  600113827000000   600113827  18.850684
# 2     185102357609940321215    NaN  600113825000000   600113825  18.850655
# 3     185102305709940324934    NaN  600113824000000   600113824  18.850640
# 4     185059980809940293254    NaN  600113809000000   600113809  18.849993
# ...                     ...    ...              ...         ...        ...
# 4995  185043996409940566509    NaN  600139941000000   600139941  18.845555
# 4996  185043904209940583567    NaN  600139946000000   600139946  18.845529
# 4997  185043885909940586979    NaN  600139947000000   600139947  18.845524
# 4998  185043286509940583320    NaN  600139955000000   600139955  18.845357
# 4999  184944290809940382816    NaN  600120005000000   600120005  18.828970
#
#        LONGITUD                                       geometry  \
# 0    -99.675176  POINT (-99.67517606975338 18.850712639013025)
# 1    -99.675383  POINT (-99.67538268405914 18.850683771923897)
# 2    -99.675589   POINT (-99.67558929974668 18.85065490572391)
# 3    -99.675693  POINT (-99.67569260722786 18.850640472238048)
# 4    -99.674814  POINT (-99.67481374655031 18.849992667495044)
# ...         ...                                            ...
# 4995 -99.682403  POINT (-99.68240303457748 18.845554570896226)
# 4996 -99.682877  POINT (-99.68287686379651 18.845528945283125)
# 4997 -99.682972  POINT (-99.68297163133053 18.845523851613372)
# 4998 -99.682870  POINT (-99.68286998811824 18.845357362225222)
# 4999 -99.677300  POINT (-99.67730043813887 18.828969661500107)
#
#          CLAVE_PREDIO  ESTIMADO  CURT
# 0     600113801000000         1     1
# 1     600113827000000         1     1
# 2     600113825000000         1     1
# 3     600113824000000         1     1
# 4     600113809000000         1     1
# ...               ...       ...   ...
# 4995  600139941000000         1     1
# 4996  600139946000000         1     1
# 4997  600139947000000         1     1
# 4998  600139955000000         1     1
# 4999  600120005000000         1     1
#
# [5000 rows x 16 columns]

# %%
# test_igecem = prep.data_prep_catastro(path_base, path_shp)
from tqdm import tqdm
import os
test_igecem= pd.read_csv(r'C:\Users\dlara\Downloads\test_igecem_ch.csv', encoding='utf-8-sig')
test_igecem_chunks =  np.array_split(test_igecem, os.cpu_count()-1) ##Aqui se especifica si se requiere un loc y los chunks

df_concat = pd.DataFrame()

with concurrent.futures.ThreadPoolExecutor() as executor:
    for df_chunk in tqdm(zip(executor.map(funcion, test_igecem_chunks)),total = len(test_igecem_chunks)):
        df_concat = pd.concat([df_chunk[0],df_concat], axis=0)
# Out:
#   0%|          | 0/334 [00:00<?, ?it/s]
# 600113801000000
#   0%|          | 0/334 [00:00<?, ?it/s]
#   0%|          | 0/334 [00:00<?, ?it/s]
#   0%|          | 0/333 [00:00<?, ?it/s]
#   0%|          | 0/334 [00:00<?, ?it/s]
#   0%|          | 0/334 [00:00<?, ?it/s]
#   0%|          | 0/333 [00:00<?, ?it/s]
#   0%|          | 0/333 [00:00<?, ?it/s]
#   0%|          | 0/333 [00:00<?, ?it/s]
#   0%|          | 0/333 [00:00<?, ?it/s]
#   0%|          | 0/333 [00:00<?, ?it/s]
#   0%|          | 0/333 [00:00<?, ?it/s]
#   0%|          | 0/333 [00:00<?, ?it/s]
#   0%|          | 0/333 [00:00<?, ?it/s]
#   0%|          | 0/334 [00:00<?, ?it/s]
#   0%|          | 0/333 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
# 600105621000000
# 600119002000000
# 600101032000000
# 600113504000000
# 600127751000000
# 600800832000000
# 600116015000000
# 600404806000000
# 600116218000000
# 600108606000000
# 600103519000000
# 600109204000000
# 600119811000000
# 600404229000000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\dlara\Proyectos_git\geoloc2\preparacion_datos\cruces_predialxagua.ipynb Cell 56 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/Users/dlara/Proyectos_git/geoloc2/preparacion_datos/cruces_predialxagua.ipynb#Y106sZmlsZQ%3D%3D?line=6'>7</a> df_concat = pd.DataFrame()
#       <a href='vscode-notebook-cell:/c%3A/Users/dlara/Proyectos_git/geoloc2/preparacion_datos/cruces_predialxagua.ipynb#Y106sZmlsZQ%3D%3D?line=8'>9</a> with concurrent.futures.ThreadPoolExecutor() as executor:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/dlara/Proyectos_git/geoloc2/preparacion_datos/cruces_predialxagua.ipynb#Y106sZmlsZQ%3D%3D?line=9'>10</a>     for df_chunk in tqdm(zip(executor.map(funcion, test_igecem_chunks)),total = len(test_igecem_chunks)):
#      <a href='vscode-notebook-cell:/c%3A/Users/dlara/Proyectos_git/geoloc2/preparacion_datos/cruces_predialxagua.ipynb#Y106sZmlsZQ%3D%3D?line=10'>11</a>         df_concat = pd.concat([df_chunk[0],df_concat], axis=0)
#
# File c:\Users\dlara\AppData\Local\Programs\Python\Python310\lib\site-packages\tqdm\std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Users\dlara\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:609, in Executor.map.<locals>.result_iterator()
#     606 while fs:
#     607     # Careful not to keep a reference to the popped future
#     608     if timeout is None:
# --> 609         yield fs.pop().result()
#     610     else:
#     611         yield fs.pop().result(end_time - time.monotonic())
#
# File c:\Users\dlara\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:446, in Future.result(self, timeout)
#     444     raise CancelledError()
#     445 elif self._state == FINISHED:
# --> 446     return self.__get_result()
#     447 else:
#     448     raise TimeoutError()
#
# File c:\Users\dlara\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File c:\Users\dlara\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~\Proyectos_git\geoloc2\puntos_sobre_poligono\simulacion_interpolacion.py:355, in task_chunks(chunks)
#     352 df = chunks.loc[chunks['CLAVE_PREDIO'].astype(str).str.contains(str(cve))]
#     354 assert any(df['ESTIMADO']>=1)
# --> 355 df = combinar_manzanas(df, llave='CLAVE_PREDIO')
#     356 df.reset_index(inplace=True)
#     357 df.drop_duplicates('CLAVE_PREDIO', inplace=True)
#
# File ~\Proyectos_git\geoloc2\puntos_sobre_poligono\simulacion_interpolacion.py:27, in combinar_manzanas(base, llave, buffer)
#      20 """
#      21 Lee un zip con archivos shape, une las geometrias existentes, y regresa el poligono resultante
#      22 """
#      24 # base = gpd.read_file(shp_file_zip, crs="EPSG:4326")
#      25
#      26 # base["union"] = 0
# ---> 27 base.geometry = base.geometry.buffer(buffer)
#      28 base = base.dissolve(by=llave)
#      30 border = base.geometry.to_crs("EPSG:4326")
#
# File c:\Users\dlara\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'buffer'
